# %% [markdown]
# # 1. Importing necassary libraries

# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Loading Custom Dataset

# %%
img = keras.utils.load_img("D:\Data Science\Data sets\Image Classification\Training\Arundhathi\Snapchat-1492693124.jpg")

# %%
plt.imshow(img)
plt.show()

# %%
img_train = tf.keras.utils.image_dataset_from_directory("D:\Data Science\Data sets\Image Classification\Training",labels="inferred")
#     label_mode="int",
#     class_names=None,
#     color_mode="rgb",
#     batch_size=32,
#     image_size=(256, 256),
#     shuffle=True,
#     seed=None,
#     validation_split=None,
#     subset=None,
#     interpolation="bilinear",
#     follow_links=False,
#     crop_to_aspect_ratio=False,
#     **kwargs)#
# Out:
# Found 30 files belonging to 3 classes.

# %%
img_test = tf.keras.utils.image_dataset_from_directory("D:\Data Science\Data sets\Image Classification\Testing",labels="inferred")
# Out:
# Found 6 files belonging to 3 classes.

# %%
img_train.sample_from_datasets(img_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 img_train.sample_from_datasets(img_train)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:3378, in DatasetV2.sample_from_datasets(datasets, weights, seed, stop_on_empty_dataset)
#    3374 # NOTE(mrry): We only specialize when `weights` is not a `Dataset`. When
#    3375 # it is a `Dataset`, it is possible that evaluating it has a side effect
#    3376 # the user depends on.
#    3377 if len(datasets) == 1:
# -> 3378   return datasets[0]
#    3380 def select_dataset_constant_logits(seed):
#    3381   return array_ops.squeeze(
#    3382       gen_stateless_random_ops.stateless_multinomial(
#    3383           logits, 1, seed=seed),
#    3384       axis=[0, 1])
#
# TypeError: 'BatchDataset' object is not subscriptable
